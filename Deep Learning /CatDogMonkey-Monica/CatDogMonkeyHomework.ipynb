# %% [markdown]
# # CAP 5636 2020 - Homework 3

# %%
import os
import pathlib
import random
import datetime
import functools

import numpy as np
# imports for visualization
import matplotlib.pyplot as plt
#import PIL 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, Softmax
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

from ImageDataset import DatasetCfg, create_dataset

import pickle

# %% [markdown]
# Setting up the directories for the data and temporary files.

# %%
root_dir = pathlib.WindowsPath(".")
root_temp_dir = pathlib.Path(root_dir)
code_dir = pathlib.Path(root_dir)
temp_dir = pathlib.Path(root_temp_dir, "_Temporary")
temp_dir.mkdir(exist_ok = True, parents = True)

# %%
def create_model(cfg, modelname):
    if modelname == "simple-with-dropout":
        return create_standard_CNN(cfg, 0.2)
    if modelname == "simple-no-dropout":
        return create_standard_CNN(cfg, 0.0)
    if modelname == "inception":
        return create_inception(cfg)
    if modelname == "my-network-1":
        return create_my_network_1(cfg)
    if modelname == "my-network-2":
        return create_my_network_2(cfg)
    if modelname == "my-network-3":
        return create_my_network_3(cfg)
    raise RuntimeError(f"unknown model {modelname}")

    
def create_standard_CNN(cfg, dropout = 0.2, activation = 'relu'):
    """ Create a simple model with dropout"""
    model = Sequential([
        Conv2D(16, 3, padding='same', activation=activation, input_shape=(cfg.IMG_HEIGHT, cfg.IMG_WIDTH ,3)),
        MaxPooling2D(),
        Dropout(dropout),
        Conv2D(32, 3, padding='same', activation=activation),
        MaxPooling2D(),
        Conv2D(64, 3, padding='same', activation=activation),
        MaxPooling2D(),
        Dropout(dropout),
        Flatten(),
        Dense(512, activation='relu'),
        Dense(len(cfg.CLASS_NAMES)) 
    ])
    # 
    # in this case, it does not have a softmax output... because we are using cross-validation
    model.summary()
    return model

def create_inception(cfg):
    """ Create a model starting from the feature extraction layers of an Inception v3 network, 
    pre-trained on ImageNet. Train only the classifier on top of this network. 
    """
    # https://keras.io/api/applications/
    # create the base pre-trained model
    base_model = InceptionV3(weights='imagenet', include_top=False)

    # add a global spatial average pooling layer
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    # let's add a fully-connected layer
    x = Dense(1024, activation='relu')(x)
    # and a logistic layer -- let's say we have 200 classes
    #predictions = Dense(200, activation='softmax')(x)
    predictions = Dense(3)(x)
    # this is the model we will train
    model = Model(inputs=base_model.input, outputs=predictions)
    # first: train only the top layers (which were randomly initialized)
    # i.e. freeze all convolutional InceptionV3 layers
    for layer in base_model.layers:
        layer.trainable = False
    model.summary()
    return model

# %%
def create_my_network_1(cfg):
    """Replace this model with an alternative model"""
    model = Sequential()
    model.add(Conv2D(16, 7, padding='same', activation='relu', input_shape=(cfg.IMG_HEIGHT, cfg.IMG_WIDTH ,3)));
    model.add(Conv2D(32, 7, padding='same', activation='relu', input_shape=(cfg.IMG_HEIGHT, cfg.IMG_WIDTH ,3)));
    model.add(Flatten())
    model.add(Dense(20, activation='relu'))
#   model.add(Dropout(0.3))
    model.add(Dense(len(cfg.CLASS_NAMES)))
#   model.add(Dense(3, activation='softmax'))
    return model

# %%
def create_my_network_2(cfg):
    """Replace this model with an alternative model"""
    model = Sequential()
    model.add(Conv2D(32, 7, padding='same', activation='relu', input_shape=(cfg.IMG_HEIGHT, cfg.IMG_WIDTH ,3)));
    model.add(Flatten())
    model.add(Dense(25, activation='relu'))
#   model.add(Dropout(0.3))
    model.add(Dense(len(cfg.CLASS_NAMES))) 
#   model.add(Dense(3, activation='softmax'))
    return model

# %%
def create_my_network_3(cfg):
    """Replace this model with an alternative model"""
    model = Sequential()
    model.add(Conv2D(16, 7, padding='same', activation='relu', input_shape=(cfg.IMG_HEIGHT, cfg.IMG_WIDTH ,3)));
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
#   model.add(Dropout(0.3))
    model.add(Dense(len(cfg.CLASS_NAMES))) 
#   model.add(Dense(3, activation='softmax'))
    return model

# %%
class ExperimentSpecification:
    """Contains the various parameters of the experiment"""
    def __init__(self, datasetname = None, modelname = None):
        self.modelname = modelname
        self.datasetname = datasetname
        self.optimizer = "adam"
        self.target_epochs = 5
        
    def get_expname(self):
        """Returns a name generated from the parameters that can distinguish between 
        the experiments. The idea is that the different experiments will be put into 
        different directories"""
        return self.modelname + "-" + self.optimizer

# %%
class ExperimentResults:
    """ The class which will be saved and contains the experiment results """
    def __init__(self, exp_spec):
        self.exp_spec = exp_spec
        self.expname = exp_spec.get_expname()
        self.modelname = exp_spec.modelname
        self.epochs_trained = 0
        self.metrics = {'loss' : [], 'accuracy': [], 'val_loss': [], 'val_accuracy' : []}

# %%
def run_training_experiment(exp_spec):
    """ Runs a training experiment, returns the experimental results. The same function can be used 
    to return the experimental result"""
    # the directory of the current setup in temp
    temp_model_dir = pathlib.Path(temp_dir, exp_spec.get_expname())
    temp_model_dir.mkdir(exist_ok = True, parents = True)
    # paths to various files
    er_path = pathlib.Path(temp_model_dir, exp_spec.get_expname() + "_exprecord.pkl")
    checkpoint_path = pathlib.Path(temp_model_dir, "checkpoint.ckpt")
        
    exp_spec.dataset_dir = pathlib.WindowsPath(root_dir, exp_spec.datasetname)
    if not exp_spec.dataset_dir.exists():
        raise RuntimeError(f"Dataset directory does not exist {exp_spec.dataset_dir}")
    cfg = DatasetCfg(path_to_data = exp_spec.dataset_dir)
    
    # Load or create the experiment results. If we are done, just return that.
    if er_path.exists():
        with open(er_path, 'rb') as f:
            er = pickle.load(f)
        print(f"> > > Loaded the previous experiment results successfully from {er_path}")
        if er.epochs_trained >= exp_spec.target_epochs:
            print(f"> > > The experiment results have training epochs {er.epochs_trained},"
                  f" which is more than the one requested {exp_spec.target_epochs}, returning it without further training.")
            return er
    else:
        er = ExperimentResults(exp_spec)
    
    model = create_model(cfg, exp_spec.modelname)    
    # if there is something to load, load it back
    if er.epochs_trained > 0:
        model.load_weights(str(checkpoint_path))
    model.compile(optimizer=exp_spec.optimizer,
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
    # callback for saving the model's weights
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=str(checkpoint_path),
                                                     save_weights_only=True,
                                                     verbose=1)
    # create the training data
    train_data_gen, validation_data_gen = create_dataset(cfg)

    # proceeding in steps of only one epoch at a time, save the results etc.
    while er.epochs_trained < exp_spec.target_epochs:
        print(f"> > > Training {exp_spec.get_expname()} epoch {er.epochs_trained + 1} out of {exp_spec.target_epochs}")
        history = model.fit(
            train_data_gen,
            steps_per_epoch= cfg.training_count // cfg.BATCH_SIZE,
            epochs=1,
            validation_data=validation_data_gen,
            validation_steps= cfg.validation_count // cfg.BATCH_SIZE,
            callbacks=[cp_callback]
        )
        # copy the data
        er.epochs_trained = er.epochs_trained + 1
        for metric in ['loss', 'accuracy', 'val_loss', 'val_accuracy']:
            er.metrics[metric].append(history.history[metric][0])
        # update the accuracy etc here
        with open(er_path, 'wb') as f:
            # Pickle the experiment results
            pickle.dump(er, f)
    print(f"> > > Training of the requested number of epochs {exp_spec.target_epochs} done successfully.")
    return er

# %%
# Run all the specified experiments 
ds_name = "."
modelnames = ["simple-with-dropout", "simple-no-dropout", "inception", "my-network-1", "my-network-2", "my-network-3"]
ers = dict()

for modelname in modelnames:
    exp_spec = ExperimentSpecification(datasetname = ds_name, modelname = modelname)
    exp_spec.target_epochs = 12
    er = run_training_experiment(exp_spec)
    ers[modelname] = er
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               25690624
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 25,715,747
# Trainable params: 25,715,747
# Non-trainable params: 0
# _________________________________________________________________
# Image shape:  (224, 224, 3)
# Label:  [False  True False]
# > > > Training simple-with-dropout-adam epoch 1 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 10.8496 - accuracy: 0.3333
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 19s 5s/step - loss: 9.5690 - accuracy: 0.3359 - val_loss: 1.3566 - val_accuracy: 0.3828
# > > > Training simple-with-dropout-adam epoch 2 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.6397 - accuracy: 0.3542
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 15s 4s/step - loss: 1.6903 - accuracy: 0.3516 - val_loss: 1.1704 - val_accuracy: 0.3516
# > > > Training simple-with-dropout-adam epoch 3 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.3489 - accuracy: 0.3021
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 1.2771 - accuracy: 0.3359 - val_loss: 1.0880 - val_accuracy: 0.3281
# > > > Training simple-with-dropout-adam epoch 4 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.1010 - accuracy: 0.3438
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 22s 5s/step - loss: 1.0960 - accuracy: 0.3750 - val_loss: 1.0921 - val_accuracy: 0.3594
# > > > Training simple-with-dropout-adam epoch 5 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.0875 - accuracy: 0.6458
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 24s 6s/step - loss: 1.0873 - accuracy: 0.6094 - val_loss: 1.0919 - val_accuracy: 0.3281
# > > > Training simple-with-dropout-adam epoch 6 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.0774 - accuracy: 0.5208
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 1.0753 - accuracy: 0.5234 - val_loss: 1.0591 - val_accuracy: 0.4062
# > > > Training simple-with-dropout-adam epoch 7 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.0197 - accuracy: 0.6667
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 13s 3s/step - loss: 1.0538 - accuracy: 0.5625 - val_loss: 0.9728 - val_accuracy: 0.6328
# > > > Training simple-with-dropout-adam epoch 8 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.9797 - accuracy: 0.5833
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 49s 12s/step - loss: 0.9551 - accuracy: 0.6328 - val_loss: 0.8481 - val_accuracy: 0.7266
# > > > Training simple-with-dropout-adam epoch 9 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.8811 - accuracy: 0.5833
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 13s 3s/step - loss: 0.8590 - accuracy: 0.6172 - val_loss: 0.9999 - val_accuracy: 0.5234
# > > > Training simple-with-dropout-adam epoch 10 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.8107 - accuracy: 0.6875
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 28s 7s/step - loss: 0.7905 - accuracy: 0.7031 - val_loss: 1.1738 - val_accuracy: 0.4219
# > > > Training simple-with-dropout-adam epoch 11 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.7475 - accuracy: 0.6458
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.7158 - accuracy: 0.6875 - val_loss: 0.6378 - val_accuracy: 0.7266
# > > > Training simple-with-dropout-adam epoch 12 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.6827 - accuracy: 0.6667
# Epoch 00001: saving model to _Temporary\simple-with-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.6544 - accuracy: 0.7109 - val_loss: 1.0327 - val_accuracy: 0.4844
# > > > Training of the requested number of epochs 12 done successfully.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               25690624
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 25,715,747
# Trainable params: 25,715,747
# Non-trainable params: 0
# _________________________________________________________________
# Image shape:  (224, 224, 3)
# Label:  [ True False False]
# > > > Training simple-no-dropout-adam epoch 1 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 3.5093 - accuracy: 0.2500
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 42s 11s/step - loss: 3.1319 - accuracy: 0.2344 - val_loss: 1.5050 - val_accuracy: 0.3359
# > > > Training simple-no-dropout-adam epoch 2 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 1s - loss: 1.1535 - accuracy: 0.4167
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 1.1158 - accuracy: 0.4375 - val_loss: 0.9214 - val_accuracy: 0.5312
# > > > Training simple-no-dropout-adam epoch 3 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 1s - loss: 0.9419 - accuracy: 0.6562
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 23s 6s/step - loss: 0.9318 - accuracy: 0.6641 - val_loss: 0.8710 - val_accuracy: 0.6719
# > > > Training simple-no-dropout-adam epoch 4 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.8616 - accuracy: 0.6979
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.8590 - accuracy: 0.6484 - val_loss: 0.7977 - val_accuracy: 0.5781
# > > > Training simple-no-dropout-adam epoch 5 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.7780 - accuracy: 0.6042
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 26s 7s/step - loss: 0.7792 - accuracy: 0.6328 - val_loss: 0.7339 - val_accuracy: 0.6328
# > > > Training simple-no-dropout-adam epoch 6 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 1s - loss: 0.7191 - accuracy: 0.6354
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.7127 - accuracy: 0.6719 - val_loss: 0.6132 - val_accuracy: 0.7734
# > > > Training simple-no-dropout-adam epoch 7 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.6310 - accuracy: 0.7604
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 36s 9s/step - loss: 0.6006 - accuracy: 0.7891 - val_loss: 0.4485 - val_accuracy: 0.8984
# > > > Training simple-no-dropout-adam epoch 8 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 1s - loss: 0.4702 - accuracy: 0.8542
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 0.4670 - accuracy: 0.8594 - val_loss: 0.3326 - val_accuracy: 0.9062
# > > > Training simple-no-dropout-adam epoch 9 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.3381 - accuracy: 0.8854
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.3406 - accuracy: 0.8828 - val_loss: 0.2975 - val_accuracy: 0.8984
# > > > Training simple-no-dropout-adam epoch 10 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 1s - loss: 0.2736 - accuracy: 0.8958
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 37s 9s/step - loss: 0.2697 - accuracy: 0.8828 - val_loss: 0.2441 - val_accuracy: 0.9219
# > > > Training simple-no-dropout-adam epoch 11 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.2428 - accuracy: 0.9062
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.2583 - accuracy: 0.8984 - val_loss: 0.1547 - val_accuracy: 0.9609
# > > > Training simple-no-dropout-adam epoch 12 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 1s - loss: 0.1725 - accuracy: 0.9271
# Epoch 00001: saving model to _Temporary\simple-no-dropout-adam\checkpoint.ckpt
# 4/4 [==============================] - 27s 7s/step - loss: 0.1582 - accuracy: 0.9375 - val_loss: 0.1018 - val_accuracy: 0.9688
# > > > Training of the requested number of epochs 12 done successfully.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 3 96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 3 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 8 5120        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 8 240         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 8 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 1 138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 576         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, None, None, 1 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 6 12288       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 4 9216        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 9 55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 4 144         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 9 288         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 4 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 9 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, None, None, 1 0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 6 12288       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 6 76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 9 82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 3 6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 6 192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 6 192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 96          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 9 55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 4 144         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 9 288         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 4 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 9 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 9 82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 6 16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 6 192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 9 288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 192         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 6 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 9 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 6 192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 6 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 9 55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 4 144         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 9 288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 4 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 9 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 9 82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 6 18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 6 192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 6 192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 9 288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 6 192         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 6 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 9 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 6 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 6 192         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 6 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 9 55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 9 288         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 9 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 9 82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 1152        conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 9 288         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 9 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 1 384         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 384         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 1 114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 1 384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 384         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 1 384         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 1 576         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 576         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 1 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 1 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 480         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 1 179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 1 480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 1 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 1 480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 1 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 1 179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 1 480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 1 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 1 215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 1 576         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 1 576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 1 576         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 1 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 1 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# ...
# Epoch 00001: saving model to _Temporary\inception-adam\checkpoint.ckpt
# 4/4 [==============================] - 57s 14s/step - loss: 0.0408 - accuracy: 0.9922 - val_loss: 0.0044 - val_accuracy: 1.0000
# > > > Training inception-adam epoch 8 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 8s - loss: 0.0794 - accuracy: 0.9896
# Epoch 00001: saving model to _Temporary\inception-adam\checkpoint.ckpt
# 4/4 [==============================] - 54s 14s/step - loss: 0.0866 - accuracy: 0.9844 - val_loss: 0.0052 - val_accuracy: 1.0000
# > > > Training inception-adam epoch 9 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 8s - loss: 0.0118 - accuracy: 1.0000
# Epoch 00001: saving model to _Temporary\inception-adam\checkpoint.ckpt
# 4/4 [==============================] - 54s 14s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# > > > Training inception-adam epoch 10 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.0082 - accuracy: 1.0000
# Epoch 00001: saving model to _Temporary\inception-adam\checkpoint.ckpt
# 4/4 [==============================] - 61s 15s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# > > > Training inception-adam epoch 11 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 9s - loss: 0.0306 - accuracy: 0.9792
# Epoch 00001: saving model to _Temporary\inception-adam\checkpoint.ckpt
# 4/4 [==============================] - 57s 14s/step - loss: 0.0247 - accuracy: 0.9844 - val_loss: 0.0075 - val_accuracy: 1.0000
# > > > Training inception-adam epoch 12 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 9s - loss: 0.0138 - accuracy: 1.0000
# Epoch 00001: saving model to _Temporary\inception-adam\checkpoint.ckpt
# 4/4 [==============================] - 56s 14s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# > > > Training of the requested number of epochs 12 done successfully.
# Image shape:  (224, 224, 3)
# Label:  [False False  True]
# > > > Training my-network-1-adam epoch 1 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 13s - loss: 34.0903 - accuracy: 0.3333
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 65s 16s/step - loss: 28.1167 - accuracy: 0.3203 - val_loss: 2.0575 - val_accuracy: 0.3828
# > > > Training my-network-1-adam epoch 2 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 1.4048 - accuracy: 0.3958
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 58s 14s/step - loss: 1.3106 - accuracy: 0.3906 - val_loss: 0.9558 - val_accuracy: 0.3359
# > > > Training my-network-1-adam epoch 3 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 1.1403 - accuracy: 0.3333
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 58s 14s/step - loss: 1.0915 - accuracy: 0.4062 - val_loss: 0.8455 - val_accuracy: 0.7891
# > > > Training my-network-1-adam epoch 4 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.8339 - accuracy: 0.6875
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 57s 14s/step - loss: 0.8192 - accuracy: 0.6797 - val_loss: 0.6150 - val_accuracy: 0.8281
# > > > Training my-network-1-adam epoch 5 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.5547 - accuracy: 0.8646
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 56s 14s/step - loss: 0.5051 - accuracy: 0.8828 - val_loss: 0.2439 - val_accuracy: 0.9375
# > > > Training my-network-1-adam epoch 6 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.7459 - accuracy: 0.7396
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 57s 14s/step - loss: 1.3803 - accuracy: 0.6250 - val_loss: 0.3188 - val_accuracy: 0.9297
# > > > Training my-network-1-adam epoch 7 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.5843 - accuracy: 0.8021
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 56s 14s/step - loss: 0.5836 - accuracy: 0.8047 - val_loss: 0.5343 - val_accuracy: 0.7656
# > > > Training my-network-1-adam epoch 8 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.4155 - accuracy: 0.8438
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 59s 15s/step - loss: 0.4449 - accuracy: 0.8359 - val_loss: 0.2772 - val_accuracy: 0.9062
# > > > Training my-network-1-adam epoch 9 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.4684 - accuracy: 0.8750
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 56s 14s/step - loss: 0.6665 - accuracy: 0.7812 - val_loss: 0.4899 - val_accuracy: 0.8984
# > > > Training my-network-1-adam epoch 10 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.5544 - accuracy: 0.9271
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 59s 15s/step - loss: 0.5683 - accuracy: 0.9062 - val_loss: 0.7255 - val_accuracy: 0.5859
# > > > Training my-network-1-adam epoch 11 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.5926 - accuracy: 0.8438
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 61s 15s/step - loss: 0.5881 - accuracy: 0.8594 - val_loss: 0.4368 - val_accuracy: 0.8672
# > > > Training my-network-1-adam epoch 12 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 0.3048 - accuracy: 0.9479
# Epoch 00001: saving model to _Temporary\my-network-1-adam\checkpoint.ckpt
# 4/4 [==============================] - 58s 14s/step - loss: 0.2654 - accuracy: 0.9453 - val_loss: 0.4279 - val_accuracy: 0.8906
# > > > Training of the requested number of epochs 12 done successfully.
# Image shape:  (224, 224, 3)
# Label:  [False  True False]
# > > > Training my-network-2-adam epoch 1 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 4s - loss: 27.8347 - accuracy: 0.2604
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 24s 6s/step - loss: 23.8861 - accuracy: 0.2734 - val_loss: 9.6134 - val_accuracy: 0.3281
# > > > Training my-network-2-adam epoch 2 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 3.7235 - accuracy: 0.3854
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 21s 5s/step - loss: 3.0785 - accuracy: 0.3750 - val_loss: 1.0890 - val_accuracy: 0.4062
# > > > Training my-network-2-adam epoch 3 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 1.0818 - accuracy: 0.5208
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 18s 4s/step - loss: 1.0819 - accuracy: 0.5000 - val_loss: 1.0796 - val_accuracy: 0.5469
# > > > Training my-network-2-adam epoch 4 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 1.0721 - accuracy: 0.4896
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 18s 4s/step - loss: 1.0689 - accuracy: 0.5234 - val_loss: 1.0513 - val_accuracy: 0.4844
# > > > Training my-network-2-adam epoch 5 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 1.0722 - accuracy: 0.4896
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 57s 14s/step - loss: 1.0630 - accuracy: 0.4922 - val_loss: 0.9593 - val_accuracy: 0.6953
# > > > Training my-network-2-adam epoch 6 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 0.9567 - accuracy: 0.6875
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 18s 4s/step - loss: 0.9555 - accuracy: 0.6719 - val_loss: 0.9300 - val_accuracy: 0.8672
# > > > Training my-network-2-adam epoch 7 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 0.8829 - accuracy: 0.9062
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 80s 20s/step - loss: 0.8646 - accuracy: 0.8750 - val_loss: 0.6577 - val_accuracy: 0.9375
# > > > Training my-network-2-adam epoch 8 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 0.5821 - accuracy: 0.8125
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 18s 5s/step - loss: 0.5685 - accuracy: 0.8203 - val_loss: 0.3321 - val_accuracy: 0.9062
# > > > Training my-network-2-adam epoch 9 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 0.2510 - accuracy: 0.9062
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 63s 16s/step - loss: 0.2268 - accuracy: 0.9219 - val_loss: 0.0992 - val_accuracy: 0.9844
# > > > Training my-network-2-adam epoch 10 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 4s - loss: 0.1344 - accuracy: 0.9479
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 59s 15s/step - loss: 0.1198 - accuracy: 0.9609 - val_loss: 0.0299 - val_accuracy: 1.0000
# > > > Training my-network-2-adam epoch 11 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 0.0262 - accuracy: 1.0000
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 18s 4s/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# > > > Training my-network-2-adam epoch 12 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 0.0178 - accuracy: 1.0000
# Epoch 00001: saving model to _Temporary\my-network-2-adam\checkpoint.ckpt
# 4/4 [==============================] - 59s 15s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# > > > Training of the requested number of epochs 12 done successfully.
# Image shape:  (224, 224, 3)
# Label:  [False  True False]
# > > > Training my-network-3-adam epoch 1 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 3s - loss: 20.8059 - accuracy: 0.3333
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 30s 7s/step - loss: 17.0178 - accuracy: 0.3359 - val_loss: 7.3473 - val_accuracy: 0.3359
# > > > Training my-network-3-adam epoch 2 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 6.3125 - accuracy: 0.3333
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 14s 4s/step - loss: 5.3744 - accuracy: 0.3438 - val_loss: 1.3930 - val_accuracy: 0.3203
# > > > Training my-network-3-adam epoch 3 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 11s - loss: 1.1710 - accuracy: 0.3646
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 38s 10s/step - loss: 1.1684 - accuracy: 0.3516 - val_loss: 1.1329 - val_accuracy: 0.3438
# > > > Training my-network-3-adam epoch 4 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.1574 - accuracy: 0.2917
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 1.1389 - accuracy: 0.3516 - val_loss: 1.0959 - val_accuracy: 0.3594
# > > > Training my-network-3-adam epoch 5 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.0957 - accuracy: 0.3750
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 13s 3s/step - loss: 1.0953 - accuracy: 0.3594 - val_loss: 1.0854 - val_accuracy: 0.4609
# > > > Training my-network-3-adam epoch 6 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 1.0827 - accuracy: 0.4896
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 1.0826 - accuracy: 0.4766 - val_loss: 0.9954 - val_accuracy: 0.6562
# > > > Training my-network-3-adam epoch 7 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.9973 - accuracy: 0.5000
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.9677 - accuracy: 0.5000 - val_loss: 0.8078 - val_accuracy: 0.6172
# > > > Training my-network-3-adam epoch 8 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.8523 - accuracy: 0.6458
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.8221 - accuracy: 0.6875 - val_loss: 0.6496 - val_accuracy: 0.8047
# > > > Training my-network-3-adam epoch 9 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.5507 - accuracy: 0.8333
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 0.6997 - accuracy: 0.7266 - val_loss: 0.6754 - val_accuracy: 0.7109
# > > > Training my-network-3-adam epoch 10 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.6620 - accuracy: 0.7604
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 12s 3s/step - loss: 0.6427 - accuracy: 0.7891 - val_loss: 0.6333 - val_accuracy: 0.8438
# > > > Training my-network-3-adam epoch 11 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.6676 - accuracy: 0.8854
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 0.6795 - accuracy: 0.8906 - val_loss: 0.6590 - val_accuracy: 0.7734
# > > > Training my-network-3-adam epoch 12 out of 12
# Train for 4 steps, validate for 4 steps
# 3/4 [=====================>........] - ETA: 2s - loss: 0.7593 - accuracy: 0.6771
# Epoch 00001: saving model to _Temporary\my-network-3-adam\checkpoint.ckpt
# 4/4 [==============================] - 11s 3s/step - loss: 0.7219 - accuracy: 0.7422 - val_loss: 0.6344 - val_accuracy: 0.9453
# > > > Training of the requested number of epochs 12 done successfully.

# %%
#plt.subplot(2,3,i+1)
def plot_experiment_results(er):
    #plt.title(er.exp_spec.get_expname())
    plt.plot(er.metrics['loss'])
    plt.plot(er.metrics['val_loss'])
    
def plot_metric(metric, ers):
    plt.figure()
    ax = plt.gca()
    ax.set_title(metric)
    ax.set_xlabel("Epochs")
    ax.set_ylabel(metric)
    for name in ers:
        plt.plot(ers[name].metrics[metric], label=name)
    ax.legend()
    
#  for name in ers:
#    plot_experiment_results(ers[name])

plot_metric('loss', ers)
plot_metric('val_loss', ers)
plot_metric('accuracy', ers)
plot_metric('val_accuracy', ers)
